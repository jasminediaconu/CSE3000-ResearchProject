# %%
from transformers import logging

import random
import os

import tensorflow as tf
from tensorflow import keras
from keras import layers

import matplotlib.pyplot as plt
import re
import string

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
# Out:
# 2022-06-18 12:37:37.128522: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-18 12:37:37.128548: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# setting up seed
seed = 123

os.environ['PYTHONHASHSEED']=str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

logging.set_verbosity_error()

# %%
BATCH_SIZE = 128 # batch size used on the train and validation set
NUM_TRAIN_EPOCHS = 5 # number of iterations for the model training
MAX_SEQ_LENGTH = 128 # used to cut/pad the text into tokens

# %%
# Loading the dataset
path = '../../datasets/'
taxonomy = pd.read_csv(path + 'taxonomy.csv')
queries, labels = taxonomy['query'].to_numpy(), taxonomy['label'].to_numpy()

# %%
# Encoding the labels to binary values
bin_encoder = LabelEncoder()
labels = bin_encoder.fit_transform(labels)

# %%
val_split = 250
test_split = 500
train_split = 50

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = queries[labels == 1], labels[labels == 1]
x_negatives, y_negatives = queries[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled human queries pool: {len(pool_negatives)}")
print(f"Unlabeled informational queries pool: {len(pool_positives)}")
# Out:
# Initial training set size: 100
# Validation set size: 500
# Testing set size: 1000
# Unlabeled human queries pool: 1304
# Unlabeled informational queries pool: 2096
# 2022-06-18 12:37:41.446512: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-18 12:37:41.446708: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-18 12:37:41.446740: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jasmine): /proc/driver/nvidia/version does not exist
# 2022-06-18 12:37:41.447268: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Cleaning up the text and vectorizing it
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", ""
    )

vectorizer = layers.TextVectorization(
    3000, standardize=custom_standardization, output_sequence_length=MAX_SEQ_LENGTH
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE)
)

def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label

train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(BATCH_SIZE).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(BATCH_SIZE).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(MAX_SEQ_LENGTH,)),
            layers.Embedding(input_dim=3000, output_dim=MAX_SEQ_LENGTH),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(12, activation="relu"),
            layers.Dropout(0.3),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %%
def train_active_learning_model(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=4,
    sampling_size=100,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives()
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "LSTM_AL_Balanced.h5", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(500).batch(BATCH_SIZE),
        epochs=NUM_TRAIN_EPOCHS,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = tf.where(tf.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                round((false_positives / total), 2),
                round((false_negatives / total), 2),
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives()
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(500).batch(BATCH_SIZE),
            validation_data=val_dataset,
            epochs=NUM_TRAIN_EPOCHS,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("LSTM_AL_Balanced.h5")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model

# %%
active_learning_model = train_active_learning_model(
    train_dataset, pool_negatives, pool_positives, val_d ataset, test_dataset)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 128, 128)          384000
#
#  bidirectional (Bidirectiona  (None, 128, 64)          41216
#  l)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 12)                780
#
#  dropout (Dropout)           (None, 12)                0
#
#  dense_1 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 426,009
# Trainable params: 426,009
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 100 samples
# Epoch 1/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6972 - binary_accuracy: 0.4800 - false_negatives: 3.0000 - false_positives: 49.0000
# Epoch 1: val_loss improved from inf to 0.69222, saving model to LSTM_AL_Balanced.h5
# 1/1 [==============================] - 6s 6s/step - loss: 0.6972 - binary_accuracy: 0.4800 - false_negatives: 3.0000 - false_positives: 49.0000 - val_loss: 0.6922 - val_binary_accuracy: 0.5000 - val_false_negatives: 0.0000e+00 - val_false_positives: 250.0000
# Epoch 2/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6877 - binary_accuracy: 0.5000 - false_negatives: 0.0000e+00 - false_positives: 50.0000
# Epoch 2: val_loss improved from 0.69222 to 0.68946, saving model to LSTM_AL_Balanced.h5
# 1/1 [==============================] - 0s 431ms/step - loss: 0.6877 - binary_accuracy: 0.5000 - false_negatives: 0.0000e+00 - false_positives: 50.0000 - val_loss: 0.6895 - val_binary_accuracy: 0.5000 - val_false_negatives: 0.0000e+00 - val_false_positives: 250.0000
# Epoch 3/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6791 - binary_accuracy: 0.6200 - false_negatives: 2.0000 - false_positives: 36.0000
# Epoch 3: val_loss improved from 0.68946 to 0.68721, saving model to LSTM_AL_Balanced.h5
# 1/1 [==============================] - 0s 376ms/step - loss: 0.6791 - binary_accuracy: 0.6200 - false_negatives: 2.0000 - false_positives: 36.0000 - val_loss: 0.6872 - val_binary_accuracy: 0.5000 - val_false_negatives: 0.0000e+00 - val_false_positives: 250.0000
# Epoch 4/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6687 - binary_accuracy: 0.6000 - false_negatives: 1.0000 - false_positives: 39.0000
# Epoch 4: val_loss improved from 0.68721 to 0.68549, saving model to LSTM_AL_Balanced.h5
# 1/1 [==============================] - 0s 377ms/step - loss: 0.6687 - binary_accuracy: 0.6000 - false_negatives: 1.0000 - false_positives: 39.0000 - val_loss: 0.6855 - val_binary_accuracy: 0.5120 - val_false_negatives: 0.0000e+00 - val_false_positives: 244.0000
# Epoch 5/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6614 - binary_accuracy: 0.7400 - false_negatives: 0.0000e+00 - false_positives: 26.0000
# Epoch 5: val_loss improved from 0.68549 to 0.68284, saving model to LSTM_AL_Balanced.h5
# 1/1 [==============================] - 0s 390ms/step - loss: 0.6614 - binary_accuracy: 0.7400 - false_negatives: 0.0000e+00 - false_positives: 26.0000 - val_loss: 0.6828 - val_binary_accuracy: 0.6020 - val_false_negatives: 4.0000 - val_false_positives: 195.0000
# 8/8 [==============================] - 1s 40ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 0.0, Number of ones incorrectly classified: 288.0
# Sample ratio for positives: 0.5, Sample ratio for negatives:0.5
# Starting training with 200 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 2/2 [==============================] - ETA: 0s - loss: 0.6600 - binary_accuracy: 0.7350 - false_negatives_1: 3.0000 - false_positives_1: 50.0000
# Epoch 1: val_loss improved from 0.68284 to 0.67732, saving model to LSTM_AL_Balanced.h5
# 2/2 [==============================] - 5s 1s/step - loss: 0.6600 - binary_accuracy: 0.7350 - false_negatives_1: 3.0000 - false_positives_1: 50.0000 - val_loss: 0.6773 - val_binary_accuracy: 0.6880 - val_false_negatives_1: 12.0000 - val_false_positives_1: 144.0000
# Epoch 2/5
# 2/2 [==============================] - ETA: 0s - loss: 0.6343 - binary_accuracy: 0.8450 - false_negatives_1: 0.0000e+00 - false_positives_1: 31.0000
# Epoch 2: val_loss improved from 0.67732 to 0.67094, saving model to LSTM_AL_Balanced.h5
# 2/2 [==============================] - 0s 320ms/step - loss: 0.6343 - binary_accuracy: 0.8450 - false_negatives_1: 0.0000e+00 - false_positives_1: 31.0000 - val_loss: 0.6709 - val_binary_accuracy: 0.5620 - val_false_negatives_1: 2.0000 - val_false_positives_1: 217.0000
# Epoch 3/5
# 2/2 [==============================] - ETA: 0s - loss: 0.6139 - binary_accuracy: 0.7800 - false_negatives_1: 4.0000 - false_positives_1: 40.0000
# Epoch 3: val_loss improved from 0.67094 to 0.66486, saving model to LSTM_AL_Balanced.h5
# 2/2 [==============================] - 0s 326ms/step - loss: 0.6139 - binary_accuracy: 0.7800 - false_negatives_1: 4.0000 - false_positives_1: 40.0000 - val_loss: 0.6649 - val_binary_accuracy: 0.7760 - val_false_negatives_1: 26.0000 - val_false_positives_1: 86.0000
# Epoch 4/5
# 2/2 [==============================] - ETA: 0s - loss: 0.5978 - binary_accuracy: 0.8650 - false_negatives_1: 0.0000e+00 - false_positives_1: 27.0000
# Epoch 4: val_loss improved from 0.66486 to 0.65734, saving model to LSTM_AL_Balanced.h5
# 2/2 [==============================] - 0s 326ms/step - loss: 0.5978 - binary_accuracy: 0.8650 - false_negatives_1: 0.0000e+00 - false_positives_1: 27.0000 - val_loss: 0.6573 - val_binary_accuracy: 0.7640 - val_false_negatives_1: 21.0000 - val_false_positives_1: 97.0000
# Epoch 5/5
# 2/2 [==============================] - ETA: 0s - loss: 0.5797 - binary_accuracy: 0.9250 - false_negatives_1: 1.0000 - false_positives_1: 14.0000
# Epoch 5: val_loss improved from 0.65734 to 0.64774, saving model to LSTM_AL_Balanced.h5
# 2/2 [==============================] - 0s 339ms/step - loss: 0.5797 - binary_accuracy: 0.9250 - false_negatives_1: 1.0000 - false_positives_1: 14.0000 - val_loss: 0.6477 - val_binary_accuracy: 0.7280 - val_false_negatives_1: 14.0000 - val_false_positives_1: 122.0000
# 8/8 [==============================] - 1s 45ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 15.0, Number of ones incorrectly classified: 174.0
# Sample ratio for positives: 0.92, Sample ratio for negatives:0.08
# Starting training with 300 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 3/3 [==============================] - ETA: 0s - loss: 0.5535 - binary_accuracy: 0.7733 - false_negatives_2: 5.0000 - false_positives_2: 63.0000
# Epoch 1: val_loss did not improve from 0.64774
# 3/3 [==============================] - 6s 728ms/step - loss: 0.5535 - binary_accuracy: 0.7733 - false_negatives_2: 5.0000 - false_positives_2: 63.0000 - val_loss: 0.6583 - val_binary_accuracy: 0.5100 - val_false_negatives_2: 0.0000e+00 - val_false_positives_2: 245.0000
# Epoch 2/5
# 3/3 [==============================] - ETA: 0s - loss: 0.4905 - binary_accuracy: 0.7867 - false_negatives_2: 2.0000 - false_positives_2: 62.0000
# Epoch 2: val_loss improved from 0.64774 to 0.64392, saving model to LSTM_AL_Balanced.h5
# 3/3 [==============================] - 1s 236ms/step - loss: 0.4905 - binary_accuracy: 0.7867 - false_negatives_2: 2.0000 - false_positives_2: 62.0000 - val_loss: 0.6439 - val_binary_accuracy: 0.5440 - val_false_negatives_2: 1.0000 - val_false_positives_2: 227.0000
# Epoch 3/5
# 3/3 [==============================] - ETA: 0s - loss: 0.4472 - binary_accuracy: 0.8167 - false_negatives_2: 1.0000 - false_positives_2: 54.0000
# Epoch 3: val_loss improved from 0.64392 to 0.61957, saving model to LSTM_AL_Balanced.h5
# 3/3 [==============================] - 1s 239ms/step - loss: 0.4472 - binary_accuracy: 0.8167 - false_negatives_2: 1.0000 - false_positives_2: 54.0000 - val_loss: 0.6196 - val_binary_accuracy: 0.6060 - val_false_negatives_2: 1.0000 - val_false_positives_2: 196.0000
# Epoch 4/5
# 3/3 [==============================] - ETA: 0s - loss: 0.4049 - binary_accuracy: 0.8867 - false_negatives_2: 1.0000 - false_positives_2: 33.0000
# Epoch 4: val_loss improved from 0.61957 to 0.58003, saving model to LSTM_AL_Balanced.h5
# 3/3 [==============================] - 1s 239ms/step - loss: 0.4049 - binary_accuracy: 0.8867 - false_negatives_2: 1.0000 - false_positives_2: 33.0000 - val_loss: 0.5800 - val_binary_accuracy: 0.6880 - val_false_negatives_2: 6.0000 - val_false_positives_2: 150.0000
# Epoch 5/5
# 3/3 [==============================] - ETA: 0s - loss: 0.4223 - binary_accuracy: 0.7900 - false_negatives_2: 2.0000 - false_positives_2: 61.0000
# Epoch 5: val_loss did not improve from 0.58003
# 3/3 [==============================] - 1s 226ms/step - loss: 0.4223 - binary_accuracy: 0.7900 - false_negatives_2: 2.0000 - false_positives_2: 61.0000 - val_loss: 0.5861 - val_binary_accuracy: 0.6480 - val_false_negatives_2: 3.0000 - val_false_positives_2: 173.0000
# 8/8 [==============================] - 1s 46ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 2.0, Number of ones incorrectly classified: 200.0
# Sample ratio for positives: 0.99, Sample ratio for negatives:0.01
# Starting training with 400 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 4/4 [==============================] - ETA: 0s - loss: 0.3670 - binary_accuracy: 0.8450 - false_negatives_3: 4.0000 - false_positives_3: 58.0000
# Epoch 1: val_loss did not improve from 0.58003
# 4/4 [==============================] - 6s 529ms/step - loss: 0.3670 - binary_accuracy: 0.8450 - false_negatives_3: 4.0000 - false_positives_3: 58.0000 - val_loss: 0.6246 - val_binary_accuracy: 0.6280 - val_false_negatives_3: 1.0000 - val_false_positives_3: 185.0000
# Epoch 2/5
# 4/4 [==============================] - ETA: 0s - loss: 0.2900 - binary_accuracy: 0.9250 - false_negatives_3: 3.0000 - false_positives_3: 27.0000
# Epoch 2: val_loss improved from 0.58003 to 0.53155, saving model to LSTM_AL_Balanced.h5
# 4/4 [==============================] - 1s 200ms/step - loss: 0.2900 - binary_accuracy: 0.9250 - false_negatives_3: 3.0000 - false_positives_3: 27.0000 - val_loss: 0.5315 - val_binary_accuracy: 0.7380 - val_false_negatives_3: 8.0000 - val_false_positives_3: 123.0000
# Epoch 3/5
# 4/4 [==============================] - ETA: 0s - loss: 0.2663 - binary_accuracy: 0.9450 - false_negatives_3: 7.0000 - false_positives_3: 15.0000
# Epoch 3: val_loss did not improve from 0.53155
# 4/4 [==============================] - 1s 195ms/step - loss: 0.2663 - binary_accuracy: 0.9450 - false_negatives_3: 7.0000 - false_positives_3: 15.0000 - val_loss: 0.6084 - val_binary_accuracy: 0.6760 - val_false_negatives_3: 4.0000 - val_false_positives_3: 158.0000
# Epoch 4/5
# 4/4 [==============================] - ETA: 0s - loss: 0.2341 - binary_accuracy: 0.9600 - false_negatives_3: 2.0000 - false_positives_3: 14.0000
# Epoch 4: val_loss did not improve from 0.53155
# 4/4 [==============================] - 1s 194ms/step - loss: 0.2341 - binary_accuracy: 0.9600 - false_negatives_3: 2.0000 - false_positives_3: 14.0000 - val_loss: 0.6450 - val_binary_accuracy: 0.6740 - val_false_negatives_3: 4.0000 - val_false_positives_3: 159.0000
# Epoch 5/5
# 4/4 [==============================] - ETA: 0s - loss: 0.2221 - binary_accuracy: 0.9625 - false_negatives_3: 3.0000 - false_positives_3: 12.0000
# Epoch 5: val_loss improved from 0.53155 to 0.52130, saving model to LSTM_AL_Balanced.h5
# 4/4 [==============================] - 1s 211ms/step - loss: 0.2221 - binary_accuracy: 0.9625 - false_negatives_3: 3.0000 - false_positives_3: 12.0000 - val_loss: 0.5213 - val_binary_accuracy: 0.7840 - val_false_negatives_3: 12.0000 - val_false_positives_3: 96.0000
# 8/8 [==============================] - 1s 47ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 3.0, Number of ones incorrectly classified: 118.0
# Sample ratio for positives: 0.98, Sample ratio for negatives:0.02
# Starting training with 500 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 4/4 [==============================] - ETA: 0s - loss: 0.1902 - binary_accuracy: 0.9460 - false_negatives_4: 6.0000 - false_positives_4: 21.0000
# Epoch 1: val_loss improved from 0.52130 to 0.47745, saving model to LSTM_AL_Balanced.h5
# 4/4 [==============================] - 7s 602ms/step - loss: 0.1902 - binary_accuracy: 0.9460 - false_negatives_4: 6.0000 - false_positives_4: 21.0000 - val_loss: 0.4775 - val_binary_accuracy: 0.7980 - val_false_negatives_4: 16.0000 - val_false_positives_4: 85.0000
# Epoch 2/5
# 4/4 [==============================] - ETA: 0s - loss: 0.1696 - binary_accuracy: 0.9760 - false_negatives_4: 4.0000 - false_positives_4: 8.0000
# Epoch 2: val_loss did not improve from 0.47745
# 4/4 [==============================] - 1s 255ms/step - loss: 0.1696 - binary_accuracy: 0.9760 - false_negatives_4: 4.0000 - false_positives_4: 8.0000 - val_loss: 0.6114 - val_binary_accuracy: 0.7640 - val_false_negatives_4: 9.0000 - val_false_positives_4: 109.0000
# Epoch 3/5
# 4/4 [==============================] - ETA: 0s - loss: 0.1509 - binary_accuracy: 0.9840 - false_negatives_4: 2.0000 - false_positives_4: 6.0000
# Epoch 3: val_loss did not improve from 0.47745
# 4/4 [==============================] - 1s 214ms/step - loss: 0.1509 - binary_accuracy: 0.9840 - false_negatives_4: 2.0000 - false_positives_4: 6.0000 - val_loss: 0.6986 - val_binary_accuracy: 0.7460 - val_false_negatives_4: 7.0000 - val_false_positives_4: 120.0000
# Epoch 4/5
# 4/4 [==============================] - ETA: 0s - loss: 0.1337 - binary_accuracy: 0.9840 - false_negatives_4: 3.0000 - false_positives_4: 5.0000
# Epoch 4: val_loss did not improve from 0.47745
# 4/4 [==============================] - 1s 272ms/step - loss: 0.1337 - binary_accuracy: 0.9840 - false_negatives_4: 3.0000 - false_positives_4: 5.0000 - val_loss: 0.6368 - val_binary_accuracy: 0.7660 - val_false_negatives_4: 10.0000 - val_false_positives_4: 107.0000
# Epoch 5/5
# 4/4 [==============================] - ETA: 0s - loss: 0.1223 - binary_accuracy: 0.9800 - false_negatives_4: 5.0000 - false_positives_4: 5.0000
# Epoch 5: val_loss did not improve from 0.47745
# 4/4 [==============================] - 1s 209ms/step - loss: 0.1223 - binary_accuracy: 0.9800 - false_negatives_4: 5.0000 - false_positives_4: 5.0000 - val_loss: 0.7484 - val_binary_accuracy: 0.7420 - val_false_negatives_4: 6.0000 - val_false_positives_4: 123.0000
# Epoch 5: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.33920326828956604, 'binary_accuracy': 0.9010000228881836, 'false_negatives_4': 3.0, 'false_positives_4': 96.0}
# ----------------------------------------------------------------------------------------------------
