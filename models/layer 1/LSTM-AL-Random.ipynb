# %%
from transformers import logging

import random
import os

import tensorflow as tf
from tensorflow import keras
from keras import layers

import matplotlib.pyplot as plt
import re
import string

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
# Out:
# 2022-06-19 14:57:22.525220: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-19 14:57:22.525244: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# setting up seed
seed = 123

os.environ['PYTHONHASHSEED']=str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

logging.set_verbosity_error()

# %%
BATCH_SIZE = 128 # batch size used on the train and validation set
NUM_TRAIN_EPOCHS = 5 # number of iterations for the model training
MAX_SEQ_LENGTH = 128 # used to cut/pad the text into tokens

# %%
# Loading the dataset
path = '../../datasets/'
taxonomy = pd.read_csv(path + 'taxonomy.csv')

# %%
# Encoding the labels to binary values
bin_encoder = LabelEncoder()
taxonomy['label'] = bin_encoder.fit_transform(taxonomy['label'])

# %%
# Randomly sample four sets: pool of unlabeled data (68%), train set (2%), validation set (10%), test set (20%)
unlabeled_split, train_split, val_split, test_split = np.split(taxonomy.sample(frac=1, random_state=seed), [int(.68*len(taxonomy)), int(.7*len(taxonomy)), int(.8*len(taxonomy))])

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((train_split['query'], train_split['label']))
val_dataset = tf.data.Dataset.from_tensor_slices((val_split['query'], val_split['label']))
test_dataset = tf.data.Dataset.from_tensor_slices((test_split['query'], test_split['label']))

pool_unlabeled = tf.data.Dataset.from_tensor_slices((unlabeled_split['query'], unlabeled_split['label']))

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled pool: {len(pool_unlabeled)}")
# Out:
# Initial training set size: 100
# Validation set size: 500
# Testing set size: 1000
# Unlabeled pool: 3400
# 2022-06-19 14:57:25.116597: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-19 14:57:25.116623: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-19 14:57:25.116640: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jasmine): /proc/driver/nvidia/version does not exist
# 2022-06-19 14:57:25.116871: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Cleaning up the text and vectorizing it
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", ""
    )

vectorizer = layers.TextVectorization(
    3000, standardize=custom_standardization, output_sequence_length=MAX_SEQ_LENGTH
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE)
)

def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label

train_dataset = train_dataset.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
pool_unlabeled = pool_unlabeled.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(BATCH_SIZE).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(BATCH_SIZE).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(MAX_SEQ_LENGTH,)),
            layers.Embedding(input_dim=3000, output_dim=MAX_SEQ_LENGTH),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(12, activation="relu"),
            layers.Dropout(0.3),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %%
def train_active_learning_model(
    train_dataset,
    pool_unlabeled,
    val_dataset,
    test_dataset,
    num_iterations=4,
    sampling_size=100,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives()
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "LSTM_AL_Random.h5", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(500).batch(BATCH_SIZE),
        epochs=NUM_TRAIN_EPOCHS,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = tf.where(tf.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        # Sample the required number of ones and zeros
        sampled_dataset = pool_unlabeled.take(int(sampling_size))
        
        # Skip the sampled data points to avoid repetition of sample
        pool_unlabeled = pool_unlabeled.skip(sampling_size)

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives()
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(500).batch(BATCH_SIZE),
            validation_data=val_dataset,
            epochs=NUM_TRAIN_EPOCHS,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("LSTM_AL_Random.h5")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model

# %%
active_learning_model = train_active_learning_model(
    train_dataset, pool_unlabeled, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 128, 128)          384000
#
#  bidirectional (Bidirectiona  (None, 128, 64)          41216
#  l)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 12)                780
#
#  dropout (Dropout)           (None, 12)                0
#
#  dense_1 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 426,009
# Trainable params: 426,009
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 100 samples
# Epoch 1/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6938 - binary_accuracy: 0.5600 - false_negatives: 1.0000 - false_positives: 43.0000
# Epoch 1: val_loss improved from inf to 0.68414, saving model to LSTM_AL_Random.h5
# 1/1 [==============================] - 4s 4s/step - loss: 0.6938 - binary_accuracy: 0.5600 - false_negatives: 1.0000 - false_positives: 43.0000 - val_loss: 0.6841 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# Epoch 2/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6867 - binary_accuracy: 0.5600 - false_negatives: 0.0000e+00 - false_positives: 44.0000
# Epoch 2: val_loss improved from 0.68414 to 0.67762, saving model to LSTM_AL_Random.h5
# 1/1 [==============================] - 0s 224ms/step - loss: 0.6867 - binary_accuracy: 0.5600 - false_negatives: 0.0000e+00 - false_positives: 44.0000 - val_loss: 0.6776 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# Epoch 3/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6831 - binary_accuracy: 0.5600 - false_negatives: 0.0000e+00 - false_positives: 44.0000
# Epoch 3: val_loss improved from 0.67762 to 0.67612, saving model to LSTM_AL_Random.h5
# 1/1 [==============================] - 0s 224ms/step - loss: 0.6831 - binary_accuracy: 0.5600 - false_negatives: 0.0000e+00 - false_positives: 44.0000 - val_loss: 0.6761 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# Epoch 4/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6740 - binary_accuracy: 0.5600 - false_negatives: 0.0000e+00 - false_positives: 44.0000
# Epoch 4: val_loss improved from 0.67612 to 0.67401, saving model to LSTM_AL_Random.h5
# 1/1 [==============================] - 0s 255ms/step - loss: 0.6740 - binary_accuracy: 0.5600 - false_negatives: 0.0000e+00 - false_positives: 44.0000 - val_loss: 0.6740 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# Epoch 5/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6639 - binary_accuracy: 0.5700 - false_negatives: 0.0000e+00 - false_positives: 43.0000
# Epoch 5: val_loss improved from 0.67401 to 0.66686, saving model to LSTM_AL_Random.h5
# 1/1 [==============================] - 0s 231ms/step - loss: 0.6639 - binary_accuracy: 0.5700 - false_negatives: 0.0000e+00 - false_positives: 43.0000 - val_loss: 0.6669 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# 8/8 [==============================] - 1s 25ms/step
# Starting training with 200 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 2/2 [==============================] - ETA: 0s - loss: 0.6664 - binary_accuracy: 0.5700 - false_negatives_1: 0.0000e+00 - false_positives_1: 86.0000
# Epoch 1: val_loss improved from 0.66686 to 0.65974, saving model to LSTM_AL_Random.h5
# 2/2 [==============================] - 4s 834ms/step - loss: 0.6664 - binary_accuracy: 0.5700 - false_negatives_1: 0.0000e+00 - false_positives_1: 86.0000 - val_loss: 0.6597 - val_binary_accuracy: 0.6080 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 196.0000
# Epoch 2/5
# 2/2 [==============================] - ETA: 0s - loss: 0.6542 - binary_accuracy: 0.5700 - false_negatives_1: 0.0000e+00 - false_positives_1: 86.0000
# Epoch 2: val_loss improved from 0.65974 to 0.64507, saving model to LSTM_AL_Random.h5
# 2/2 [==============================] - 0s 201ms/step - loss: 0.6542 - binary_accuracy: 0.5700 - false_negatives_1: 0.0000e+00 - false_positives_1: 86.0000 - val_loss: 0.6451 - val_binary_accuracy: 0.6080 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 196.0000
# Epoch 3/5
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6358 - binary_accuracy: 0.5781 - false_negatives_1: 0.0000e+00 - false_positives_1: 54.0000
# Epoch 3: val_loss improved from 0.64507 to 0.63598, saving model to LSTM_AL_Random.h5
# 2/2 [==============================] - 0s 193ms/step - loss: 0.6358 - binary_accuracy: 0.5700 - false_negatives_1: 0.0000e+00 - false_positives_1: 86.0000 - val_loss: 0.6360 - val_binary_accuracy: 0.6080 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 196.0000
# Epoch 4/5
# 2/2 [==============================] - ETA: 0s - loss: 0.6264 - binary_accuracy: 0.5750 - false_negatives_1: 0.0000e+00 - false_positives_1: 85.0000
# Epoch 4: val_loss improved from 0.63598 to 0.63244, saving model to LSTM_AL_Random.h5
# 2/2 [==============================] - 0s 197ms/step - loss: 0.6264 - binary_accuracy: 0.5750 - false_negatives_1: 0.0000e+00 - false_positives_1: 85.0000 - val_loss: 0.6324 - val_binary_accuracy: 0.6080 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 196.0000
# Epoch 5/5
# 1/2 [==============>...............] - ETA: 0s - loss: 0.6158 - binary_accuracy: 0.6641 - false_negatives_1: 0.0000e+00 - false_positives_1: 43.0000
# Epoch 5: val_loss improved from 0.63244 to 0.61124, saving model to LSTM_AL_Random.h5
# 2/2 [==============================] - 0s 191ms/step - loss: 0.6077 - binary_accuracy: 0.6400 - false_negatives_1: 0.0000e+00 - false_positives_1: 72.0000 - val_loss: 0.6112 - val_binary_accuracy: 0.6080 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 196.0000
# 8/8 [==============================] - 1s 26ms/step
# Starting training with 300 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 2/3 [===================>..........] - ETA: 0s - loss: 0.5841 - binary_accuracy: 0.6367 - false_negatives_2: 0.0000e+00 - false_positives_2: 93.0000
# Epoch 1: val_loss improved from 0.61124 to 0.57886, saving model to LSTM_AL_Random.h5
# 3/3 [==============================] - 4s 516ms/step - loss: 0.5793 - binary_accuracy: 0.6367 - false_negatives_2: 0.0000e+00 - false_positives_2: 109.0000 - val_loss: 0.5789 - val_binary_accuracy: 0.7240 - val_false_negatives_2: 1.0000 - val_false_positives_2: 137.0000
# Epoch 2/5
# 3/3 [==============================] - ETA: 0s - loss: 0.5418 - binary_accuracy: 0.7167 - false_negatives_2: 0.0000e+00 - false_positives_2: 85.0000
# Epoch 2: val_loss improved from 0.57886 to 0.54131, saving model to LSTM_AL_Random.h5
# 3/3 [==============================] - 1s 230ms/step - loss: 0.5418 - binary_accuracy: 0.7167 - false_negatives_2: 0.0000e+00 - false_positives_2: 85.0000 - val_loss: 0.5413 - val_binary_accuracy: 0.6900 - val_false_negatives_2: 0.0000e+00 - val_false_positives_2: 155.0000
# Epoch 3/5
# 3/3 [==============================] - ETA: 0s - loss: 0.5070 - binary_accuracy: 0.7733 - false_negatives_2: 2.0000 - false_positives_2: 66.0000
# Epoch 3: val_loss improved from 0.54131 to 0.51466, saving model to LSTM_AL_Random.h5
# 3/3 [==============================] - 0s 160ms/step - loss: 0.5070 - binary_accuracy: 0.7733 - false_negatives_2: 2.0000 - false_positives_2: 66.0000 - val_loss: 0.5147 - val_binary_accuracy: 0.7900 - val_false_negatives_2: 2.0000 - val_false_positives_2: 103.0000
# Epoch 4/5
# 2/3 [===================>..........] - ETA: 0s - loss: 0.4691 - binary_accuracy: 0.8711 - false_negatives_2: 1.0000 - false_positives_2: 32.0000
# Epoch 4: val_loss improved from 0.51466 to 0.49664, saving model to LSTM_AL_Random.h5
# 3/3 [==============================] - 0s 140ms/step - loss: 0.4611 - binary_accuracy: 0.8733 - false_negatives_2: 1.0000 - false_positives_2: 37.0000 - val_loss: 0.4966 - val_binary_accuracy: 0.7140 - val_false_negatives_2: 0.0000e+00 - val_false_positives_2: 143.0000
# Epoch 5/5
# 2/3 [===================>..........] - ETA: 0s - loss: 0.4211 - binary_accuracy: 0.8281 - false_negatives_2: 1.0000 - false_positives_2: 43.0000
# Epoch 5: val_loss improved from 0.49664 to 0.45037, saving model to LSTM_AL_Random.h5
# 3/3 [==============================] - 0s 150ms/step - loss: 0.4167 - binary_accuracy: 0.8433 - false_negatives_2: 1.0000 - false_positives_2: 46.0000 - val_loss: 0.4504 - val_binary_accuracy: 0.7840 - val_false_negatives_2: 3.0000 - val_false_positives_2: 105.0000
# 8/8 [==============================] - 1s 27ms/step
# Starting training with 400 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 3/4 [=====================>........] - ETA: 0s - loss: 0.3866 - binary_accuracy: 0.8776 - false_negatives_3: 14.0000 - false_positives_3: 33.0000
# Epoch 1: val_loss improved from 0.45037 to 0.38187, saving model to LSTM_AL_Random.h5
# 4/4 [==============================] - 4s 460ms/step - loss: 0.3897 - binary_accuracy: 0.8800 - false_negatives_3: 15.0000 - false_positives_3: 33.0000 - val_loss: 0.3819 - val_binary_accuracy: 0.8780 - val_false_negatives_3: 15.0000 - val_false_positives_3: 46.0000
# Epoch 2/5
# 3/4 [=====================>........] - ETA: 0s - loss: 0.3289 - binary_accuracy: 0.9219 - false_negatives_3: 8.0000 - false_positives_3: 22.0000
# Epoch 2: val_loss improved from 0.38187 to 0.36926, saving model to LSTM_AL_Random.h5
# 4/4 [==============================] - 1s 132ms/step - loss: 0.3287 - binary_accuracy: 0.9225 - false_negatives_3: 8.0000 - false_positives_3: 23.0000 - val_loss: 0.3693 - val_binary_accuracy: 0.8640 - val_false_negatives_3: 45.0000 - val_false_positives_3: 23.0000
# Epoch 3/5
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2787 - binary_accuracy: 0.9401 - false_negatives_3: 10.0000 - false_positives_3: 13.0000
# Epoch 3: val_loss did not improve from 0.36926
# 4/4 [==============================] - 0s 114ms/step - loss: 0.2739 - binary_accuracy: 0.9400 - false_negatives_3: 11.0000 - false_positives_3: 13.0000 - val_loss: 0.4774 - val_binary_accuracy: 0.7740 - val_false_negatives_3: 2.0000 - val_false_positives_3: 111.0000
# Epoch 4/5
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2644 - binary_accuracy: 0.9036 - false_negatives_3: 4.0000 - false_positives_3: 33.0000
# Epoch 4: val_loss did not improve from 0.36926
# 4/4 [==============================] - 0s 108ms/step - loss: 0.2732 - binary_accuracy: 0.8975 - false_negatives_3: 8.0000 - false_positives_3: 33.0000 - val_loss: 0.4376 - val_binary_accuracy: 0.8520 - val_false_negatives_3: 7.0000 - val_false_positives_3: 67.0000
# Epoch 5/5
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2303 - binary_accuracy: 0.9323 - false_negatives_3: 10.0000 - false_positives_3: 16.0000
# Epoch 5: val_loss improved from 0.36926 to 0.33329, saving model to LSTM_AL_Random.h5
# 4/4 [==============================] - 0s 116ms/step - loss: 0.2512 - binary_accuracy: 0.9250 - false_negatives_3: 11.0000 - false_positives_3: 19.0000 - val_loss: 0.3333 - val_binary_accuracy: 0.8640 - val_false_negatives_3: 48.0000 - val_false_positives_3: 20.0000
# 8/8 [==============================] - 1s 28ms/step
# Starting training with 500 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 4/4 [==============================] - ETA: 0s - loss: 0.2919 - binary_accuracy: 0.9020 - false_negatives_4: 19.0000 - false_positives_4: 30.0000
# Epoch 1: val_loss improved from 0.33329 to 0.29364, saving model to LSTM_AL_Random.h5
# 4/4 [==============================] - 4s 353ms/step - loss: 0.2919 - binary_accuracy: 0.9020 - false_negatives_4: 19.0000 - false_positives_4: 30.0000 - val_loss: 0.2936 - val_binary_accuracy: 0.8820 - val_false_negatives_4: 34.0000 - val_false_positives_4: 25.0000
# Epoch 2/5
# 4/4 [==============================] - ETA: 0s - loss: 0.2133 - binary_accuracy: 0.9320 - false_negatives_4: 20.0000 - false_positives_4: 14.0000
# Epoch 2: val_loss did not improve from 0.29364
# 4/4 [==============================] - 0s 123ms/step - loss: 0.2133 - binary_accuracy: 0.9320 - false_negatives_4: 20.0000 - false_positives_4: 14.0000 - val_loss: 0.3000 - val_binary_accuracy: 0.8880 - val_false_negatives_4: 19.0000 - val_false_positives_4: 37.0000
# Epoch 3/5
# 4/4 [==============================] - ETA: 0s - loss: 0.1968 - binary_accuracy: 0.9420 - false_negatives_4: 13.0000 - false_positives_4: 16.0000
# Epoch 3: val_loss did not improve from 0.29364
# 4/4 [==============================] - 0s 126ms/step - loss: 0.1968 - binary_accuracy: 0.9420 - false_negatives_4: 13.0000 - false_positives_4: 16.0000 - val_loss: 0.2998 - val_binary_accuracy: 0.8840 - val_false_negatives_4: 25.0000 - val_false_positives_4: 33.0000
# Epoch 4/5
# 4/4 [==============================] - ETA: 0s - loss: 0.1922 - binary_accuracy: 0.9520 - false_negatives_4: 10.0000 - false_positives_4: 14.0000
# Epoch 4: val_loss improved from 0.29364 to 0.29219, saving model to LSTM_AL_Random.h5
# 4/4 [==============================] - 0s 135ms/step - loss: 0.1922 - binary_accuracy: 0.9520 - false_negatives_4: 10.0000 - false_positives_4: 14.0000 - val_loss: 0.2922 - val_binary_accuracy: 0.8660 - val_false_negatives_4: 53.0000 - val_false_positives_4: 14.0000
# Epoch 5/5
# 4/4 [==============================] - ETA: 0s - loss: 0.1850 - binary_accuracy: 0.9560 - false_negatives_4: 13.0000 - false_positives_4: 9.0000
# Epoch 5: val_loss did not improve from 0.29219
# 4/4 [==============================] - 0s 125ms/step - loss: 0.1850 - binary_accuracy: 0.9560 - false_negatives_4: 13.0000 - false_positives_4: 9.0000 - val_loss: 0.3447 - val_binary_accuracy: 0.8320 - val_false_negatives_4: 75.0000 - val_false_positives_4: 9.0000
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3249202370643616, 'binary_accuracy': 0.875, 'false_negatives_4': 82.0, 'false_positives_4': 43.0}
# ----------------------------------------------------------------------------------------------------
