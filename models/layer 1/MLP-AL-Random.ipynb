# %%
from transformers import logging

import random
import os

import tensorflow as tf
from tensorflow import keras
from keras import layers

import matplotlib.pyplot as plt
import re
import string

import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
# Out:
# 2022-06-19 14:56:02.423990: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-19 14:56:02.424013: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# setting up seed
seed = 123

os.environ['PYTHONHASHSEED']=str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

logging.set_verbosity_error()

# %%
BATCH_SIZE = 128 # batch size used on the train and validation set
NUM_TRAIN_EPOCHS = 5 # number of iterations for the model training
MAX_SEQ_LENGTH = 128 # used to cut/pad the text into tokens

# %%
# Loading the dataset
path = '../../datasets/'
taxonomy = pd.read_csv(path + 'taxonomy.csv')

# %%
# Encoding the labels to binary values
bin_encoder = LabelEncoder()
taxonomy['label'] = bin_encoder.fit_transform(taxonomy['label'])

# %%
# Randomly sample four sets: pool of unlabeled data (68%), train set (2%), validation set (10%), test set (20%)
unlabeled_split, train_split, val_split, test_split = np.split(taxonomy.sample(frac=1, random_state=seed), [int(.68*len(taxonomy)), int(.7*len(taxonomy)), int(.8*len(taxonomy))])

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((train_split['query'], train_split['label']))
val_dataset = tf.data.Dataset.from_tensor_slices((val_split['query'], val_split['label']))
test_dataset = tf.data.Dataset.from_tensor_slices((test_split['query'], test_split['label']))

pool_unlabeled = tf.data.Dataset.from_tensor_slices((unlabeled_split['query'], unlabeled_split['label']))

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled pool: {len(pool_unlabeled)}")
# Out:
# Initial training set size: 100
# Validation set size: 500
# Testing set size: 1000
# Unlabeled pool: 3400
# 2022-06-19 14:56:05.105008: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-19 14:56:05.105038: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-19 14:56:05.105061: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jasmine): /proc/driver/nvidia/version does not exist
# 2022-06-19 14:56:05.105353: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Cleaning up the text and vectorizing it
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", ""
    )

vectorizer = layers.TextVectorization(
    3000, standardize=custom_standardization, output_sequence_length=MAX_SEQ_LENGTH
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(BATCH_SIZE)
)

def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label

train_dataset = train_dataset.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
pool_unlabeled = pool_unlabeled.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(BATCH_SIZE).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(BATCH_SIZE).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(MAX_SEQ_LENGTH,)),
            layers.Embedding(input_dim=3000, output_dim=MAX_SEQ_LENGTH),
            layers.GlobalMaxPool1D(),
            layers.Dense(12, activation="relu"),
            layers.Dropout(0.3),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %%
def train_active_learning_model(
    train_dataset,
    pool_unlabeled,
    val_dataset,
    test_dataset,
    num_iterations=4,
    sampling_size=200,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives()
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "MLP_AL_Random.h5", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(500).batch(BATCH_SIZE),
        epochs=NUM_TRAIN_EPOCHS,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = tf.where(tf.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        # Sample the required number of ones and zeros
        sampled_dataset = pool_unlabeled.take(int(sampling_size))
        
        # Skip the sampled data points to avoid repetition of sample
        pool_unlabeled = pool_unlabeled.skip(sampling_size)

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives()
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(500).batch(BATCH_SIZE),
            validation_data=val_dataset,
            epochs=NUM_TRAIN_EPOCHS,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("MLP_AL_Random.h5")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model

# %%
active_learning_model = train_active_learning_model(
    train_dataset, pool_unlabeled, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 128, 128)          384000
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 12)                1548
#
#  dropout (Dropout)           (None, 12)                0
#
#  dense_1 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 385,561
# Trainable params: 385,561
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 100 samples
# Epoch 1/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6930 - binary_accuracy: 0.5200 - false_negatives: 6.0000 - false_positives: 42.0000
# Epoch 1: val_loss improved from inf to 0.68876, saving model to MLP_AL_Random.h5
# 1/1 [==============================] - 1s 1s/step - loss: 0.6930 - binary_accuracy: 0.5200 - false_negatives: 6.0000 - false_positives: 42.0000 - val_loss: 0.6888 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# Epoch 2/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6838 - binary_accuracy: 0.6200 - false_negatives: 0.0000e+00 - false_positives: 38.0000
# Epoch 2: val_loss improved from 0.68876 to 0.68580, saving model to MLP_AL_Random.h5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.6838 - binary_accuracy: 0.6200 - false_negatives: 0.0000e+00 - false_positives: 38.0000 - val_loss: 0.6858 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# Epoch 3/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6821 - binary_accuracy: 0.5500 - false_negatives: 1.0000 - false_positives: 44.0000
# Epoch 3: val_loss improved from 0.68580 to 0.68430, saving model to MLP_AL_Random.h5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6821 - binary_accuracy: 0.5500 - false_negatives: 1.0000 - false_positives: 44.0000 - val_loss: 0.6843 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# Epoch 4/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6774 - binary_accuracy: 0.5800 - false_negatives: 0.0000e+00 - false_positives: 42.0000
# Epoch 4: val_loss improved from 0.68430 to 0.68236, saving model to MLP_AL_Random.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.6774 - binary_accuracy: 0.5800 - false_negatives: 0.0000e+00 - false_positives: 42.0000 - val_loss: 0.6824 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# Epoch 5/5
# 1/1 [==============================] - ETA: 0s - loss: 0.6701 - binary_accuracy: 0.5700 - false_negatives: 0.0000e+00 - false_positives: 43.0000
# Epoch 5: val_loss improved from 0.68236 to 0.68042, saving model to MLP_AL_Random.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.6701 - binary_accuracy: 0.5700 - false_negatives: 0.0000e+00 - false_positives: 43.0000 - val_loss: 0.6804 - val_binary_accuracy: 0.6080 - val_false_negatives: 0.0000e+00 - val_false_positives: 196.0000
# 8/8 [==============================] - 0s 2ms/step
# Starting training with 300 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 1/3 [=========>....................] - ETA: 1s - loss: 0.6707 - binary_accuracy: 0.6406 - false_negatives_1: 0.0000e+00 - false_positives_1: 46.0000
# Epoch 1: val_loss improved from 0.68042 to 0.66926, saving model to MLP_AL_Random.h5
# 3/3 [==============================] - 1s 168ms/step - loss: 0.6737 - binary_accuracy: 0.5967 - false_negatives_1: 0.0000e+00 - false_positives_1: 121.0000 - val_loss: 0.6693 - val_binary_accuracy: 0.6080 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 196.0000
# Epoch 2/5
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6704 - binary_accuracy: 0.5469 - false_negatives_1: 1.0000 - false_positives_1: 57.0000
# Epoch 2: val_loss improved from 0.66926 to 0.66064, saving model to MLP_AL_Random.h5
# 3/3 [==============================] - 0s 41ms/step - loss: 0.6622 - binary_accuracy: 0.6067 - false_negatives_1: 1.0000 - false_positives_1: 117.0000 - val_loss: 0.6606 - val_binary_accuracy: 0.6080 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 196.0000
# Epoch 3/5
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6567 - binary_accuracy: 0.5781 - false_negatives_1: 0.0000e+00 - false_positives_1: 54.0000
# Epoch 3: val_loss improved from 0.66064 to 0.65318, saving model to MLP_AL_Random.h5
# 3/3 [==============================] - 0s 46ms/step - loss: 0.6518 - binary_accuracy: 0.6100 - false_negatives_1: 0.0000e+00 - false_positives_1: 117.0000 - val_loss: 0.6532 - val_binary_accuracy: 0.6080 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 196.0000
# Epoch 4/5
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6485 - binary_accuracy: 0.5625 - false_negatives_1: 1.0000 - false_positives_1: 55.0000
# Epoch 4: val_loss improved from 0.65318 to 0.64610, saving model to MLP_AL_Random.h5
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6404 - binary_accuracy: 0.6433 - false_negatives_1: 1.0000 - false_positives_1: 106.0000 - val_loss: 0.6461 - val_binary_accuracy: 0.6080 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 196.0000
# Epoch 5/5
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6279 - binary_accuracy: 0.6484 - false_negatives_1: 0.0000e+00 - false_positives_1: 45.0000
# Epoch 5: val_loss improved from 0.64610 to 0.63950, saving model to MLP_AL_Random.h5
# 3/3 [==============================] - 0s 44ms/step - loss: 0.6313 - binary_accuracy: 0.6433 - false_negatives_1: 0.0000e+00 - false_positives_1: 107.0000 - val_loss: 0.6395 - val_binary_accuracy: 0.6160 - val_false_negatives_1: 0.0000e+00 - val_false_positives_1: 192.0000
# 8/8 [==============================] - 0s 3ms/step
# Starting training with 500 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6307 - binary_accuracy: 0.6797 - false_negatives_2: 0.0000e+00 - false_positives_2: 41.0000
# Epoch 1: val_loss improved from 0.63950 to 0.61861, saving model to MLP_AL_Random.h5
# 4/4 [==============================] - 1s 103ms/step - loss: 0.6220 - binary_accuracy: 0.6820 - false_negatives_2: 2.0000 - false_positives_2: 157.0000 - val_loss: 0.6186 - val_binary_accuracy: 0.6420 - val_false_negatives_2: 0.0000e+00 - val_false_positives_2: 179.0000
# Epoch 2/5
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6140 - binary_accuracy: 0.7344 - false_negatives_2: 0.0000e+00 - false_positives_2: 34.0000
# Epoch 2: val_loss improved from 0.61861 to 0.60385, saving model to MLP_AL_Random.h5
# 4/4 [==============================] - 0s 32ms/step - loss: 0.6040 - binary_accuracy: 0.7620 - false_negatives_2: 2.0000 - false_positives_2: 117.0000 - val_loss: 0.6038 - val_binary_accuracy: 0.6760 - val_false_negatives_2: 0.0000e+00 - val_false_positives_2: 162.0000
# Epoch 3/5
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5917 - binary_accuracy: 0.8047 - false_negatives_2: 1.0000 - false_positives_2: 24.0000
# Epoch 3: val_loss improved from 0.60385 to 0.58977, saving model to MLP_AL_Random.h5
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5845 - binary_accuracy: 0.7900 - false_negatives_2: 2.0000 - false_positives_2: 103.0000 - val_loss: 0.5898 - val_binary_accuracy: 0.7180 - val_false_negatives_2: 0.0000e+00 - val_false_positives_2: 141.0000
# Epoch 4/5
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5843 - binary_accuracy: 0.8125 - false_negatives_2: 1.0000 - false_positives_2: 23.0000
# Epoch 4: val_loss improved from 0.58977 to 0.57645, saving model to MLP_AL_Random.h5
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5734 - binary_accuracy: 0.7980 - false_negatives_2: 7.0000 - false_positives_2: 94.0000 - val_loss: 0.5765 - val_binary_accuracy: 0.7520 - val_false_negatives_2: 1.0000 - val_false_positives_2: 123.0000
# Epoch 5/5
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5570 - binary_accuracy: 0.8125 - false_negatives_2: 1.0000 - false_positives_2: 23.0000
# Epoch 5: val_loss improved from 0.57645 to 0.56239, saving model to MLP_AL_Random.h5
# 4/4 [==============================] - 0s 30ms/step - loss: 0.5494 - binary_accuracy: 0.8380 - false_negatives_2: 5.0000 - false_positives_2: 76.0000 - val_loss: 0.5624 - val_binary_accuracy: 0.7840 - val_false_negatives_2: 2.0000 - val_false_positives_2: 106.0000
# 8/8 [==============================] - 0s 3ms/step
# Starting training with 700 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 1/6 [====>.........................] - ETA: 4s - loss: 0.5476 - binary_accuracy: 0.8438 - false_negatives_3: 1.0000 - false_positives_3: 19.0000
# Epoch 1: val_loss improved from 0.56239 to 0.52451, saving model to MLP_AL_Random.h5
# 6/6 [==============================] - 1s 59ms/step - loss: 0.5355 - binary_accuracy: 0.8300 - false_negatives_3: 23.0000 - false_positives_3: 96.0000 - val_loss: 0.5245 - val_binary_accuracy: 0.8340 - val_false_negatives_3: 12.0000 - val_false_positives_3: 71.0000
# Epoch 2/5
# 6/6 [==============================] - ETA: 0s - loss: 0.5047 - binary_accuracy: 0.8714 - false_negatives_3: 25.0000 - false_positives_3: 65.0000
# Epoch 2: val_loss improved from 0.52451 to 0.49934, saving model to MLP_AL_Random.h5
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5047 - binary_accuracy: 0.8714 - false_negatives_3: 25.0000 - false_positives_3: 65.0000 - val_loss: 0.4993 - val_binary_accuracy: 0.8460 - val_false_negatives_3: 14.0000 - val_false_positives_3: 63.0000
# Epoch 3/5
# 6/6 [==============================] - ETA: 0s - loss: 0.4793 - binary_accuracy: 0.8843 - false_negatives_3: 26.0000 - false_positives_3: 55.0000
# Epoch 3: val_loss improved from 0.49934 to 0.47778, saving model to MLP_AL_Random.h5
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4793 - binary_accuracy: 0.8843 - false_negatives_3: 26.0000 - false_positives_3: 55.0000 - val_loss: 0.4778 - val_binary_accuracy: 0.8540 - val_false_negatives_3: 16.0000 - val_false_positives_3: 57.0000
# Epoch 4/5
# 1/6 [====>.........................] - ETA: 0s - loss: 0.4489 - binary_accuracy: 0.8984 - false_negatives_3: 5.0000 - false_positives_3: 8.0000
# Epoch 4: val_loss improved from 0.47778 to 0.45708, saving model to MLP_AL_Random.h5
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4508 - binary_accuracy: 0.8800 - false_negatives_3: 33.0000 - false_positives_3: 51.0000 - val_loss: 0.4571 - val_binary_accuracy: 0.8680 - val_false_negatives_3: 20.0000 - val_false_positives_3: 46.0000
# Epoch 5/5
# 6/6 [==============================] - ETA: 0s - loss: 0.4367 - binary_accuracy: 0.8871 - false_negatives_3: 33.0000 - false_positives_3: 46.0000
# Epoch 5: val_loss improved from 0.45708 to 0.43772, saving model to MLP_AL_Random.h5
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4367 - binary_accuracy: 0.8871 - false_negatives_3: 33.0000 - false_positives_3: 46.0000 - val_loss: 0.4377 - val_binary_accuracy: 0.8740 - val_false_negatives_3: 25.0000 - val_false_positives_3: 38.0000
# 8/8 [==============================] - 0s 3ms/step
# Starting training with 900 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/5
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4037 - binary_accuracy: 0.8973 - false_negatives_4: 36.0000 - false_positives_4: 56.0000
# Epoch 1: val_loss improved from 0.43772 to 0.39315, saving model to MLP_AL_Random.h5
# 8/8 [==============================] - 1s 53ms/step - loss: 0.4036 - binary_accuracy: 0.8978 - false_negatives_4: 36.0000 - false_positives_4: 56.0000 - val_loss: 0.3931 - val_binary_accuracy: 0.8820 - val_false_negatives_4: 26.0000 - val_false_positives_4: 33.0000
# Epoch 2/5
# 6/8 [=====================>........] - ETA: 0s - loss: 0.3730 - binary_accuracy: 0.9036 - false_negatives_4: 34.0000 - false_positives_4: 40.0000
# Epoch 2: val_loss improved from 0.39315 to 0.37021, saving model to MLP_AL_Random.h5
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3722 - binary_accuracy: 0.9000 - false_negatives_4: 43.0000 - false_positives_4: 47.0000 - val_loss: 0.3702 - val_binary_accuracy: 0.8780 - val_false_negatives_4: 27.0000 - val_false_positives_4: 34.0000
# Epoch 3/5
# 6/8 [=====================>........] - ETA: 0s - loss: 0.3472 - binary_accuracy: 0.9049 - false_negatives_4: 26.0000 - false_positives_4: 47.0000
# Epoch 3: val_loss improved from 0.37021 to 0.35010, saving model to MLP_AL_Random.h5
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3432 - binary_accuracy: 0.9089 - false_negatives_4: 32.0000 - false_positives_4: 50.0000 - val_loss: 0.3501 - val_binary_accuracy: 0.8880 - val_false_negatives_4: 30.0000 - val_false_positives_4: 26.0000
# Epoch 4/5
# 5/8 [=================>............] - ETA: 0s - loss: 0.3374 - binary_accuracy: 0.9062 - false_negatives_4: 31.0000 - false_positives_4: 29.0000
# Epoch 4: val_loss improved from 0.35010 to 0.33342, saving model to MLP_AL_Random.h5
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3318 - binary_accuracy: 0.9100 - false_negatives_4: 41.0000 - false_positives_4: 40.0000 - val_loss: 0.3334 - val_binary_accuracy: 0.8860 - val_false_negatives_4: 29.0000 - val_false_positives_4: 28.0000
# Epoch 5/5
# 6/8 [=====================>........] - ETA: 0s - loss: 0.3130 - binary_accuracy: 0.9219 - false_negatives_4: 27.0000 - false_positives_4: 33.0000
# Epoch 5: val_loss improved from 0.33342 to 0.31777, saving model to MLP_AL_Random.h5
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3123 - binary_accuracy: 0.9244 - false_negatives_4: 30.0000 - false_positives_4: 38.0000 - val_loss: 0.3178 - val_binary_accuracy: 0.8860 - val_false_negatives_4: 30.0000 - val_false_positives_4: 27.0000
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3340062201023102, 'binary_accuracy': 0.8889999985694885, 'false_negatives_4': 46.0, 'false_positives_4': 65.0}
# ----------------------------------------------------------------------------------------------------
